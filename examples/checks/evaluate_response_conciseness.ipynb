# %% [markdown]
# <h1 align="center">
#   <a href="https://uptrain.ai">
#     <img width="300" src="https://user-images.githubusercontent.com/108270398/214240695-4f958b76-c993-4ddd-8de6-8668f4d0da84.png" alt="uptrain">
#   </a>
# </h1>

# %% [markdown]
# <h1 style="text-align: center;">Evaluating Response Conciseness</h1>

# %% [markdown]
# **What is Response Conciseness?**: Response conciseness refers to the quality of a generated response in terms of being clear, brief, and to the point. A concise response effectively conveys the necessary information without unnecessary elaboration or verbosity. It focuses on addressing the core of the question or query in a straightforward manner.
#
# In the context of natural language processing and AI-generated responses, concise answers are valuable as they enhance user experience by delivering information efficiently. Extraneous details or overly complex explanations can lead to decreased clarity and user understanding.
#
# For example, if the question is "What are the advantages of adopting cloud computing?", a concise response would highlight key benefits without unnecessary details. An example concise response could be: "Cloud computing offers scalability, cost efficiency, and accessibility to resources over the internet."
#
# **Data schema**: The data schema required for evaluating response conciseness would include the same columns as mentioned in the Response Relevance example:
#
# | Column Name | Description |
# | ----------- | ----------- |
# | question | The question asked by the user |
# | response | The response generated by the model |

# %% [markdown]
# Install UpTrain by running 'pip install uptrain'

# %%
from uptrain import EvalLLM, Evals
import json

OPENAI_API_KEY = "sk-*****************"  # Insert your OpenAI key here

# %% [markdown]
# Let's first look at data with relevant responses.

# %%
good_data = [
    {
        "question": "What are the primary components of a cell?",
        "response": "A cell typically consists of a cell membrane, cytoplasm, and a nucleus. The cell membrane encloses the cell and regulates the passage of substances in and out. The cytoplasm contains organelles and other cellular structures, while the nucleus houses the genetic material."
    },
    {
        "question": "How does photosynthesis work?",
        "response": "Photosynthesis is the process by which plants, algae, and some bacteria convert light energy into chemical energy. It involves the absorption of sunlight by chlorophyll, which is used to synthesize glucose from carbon dioxide and water. Oxygen is released as a byproduct."
    },
    {
        "question": "What are the key features of the Python programming language?",
        "response": "Python is a high-level, interpreted programming language known for its readability and simplicity. It supports object-oriented, imperative, and functional programming paradigms. Python has a large standard library, dynamic typing, and automatic memory management."
    },
    {
        "question": "Explain the theory of relativity.",
        "response": "The theory of relativity, developed by Albert Einstein, consists of two major parts: special relativity and general relativity. Special relativity deals with objects moving at constant speeds, particularly those moving close to the speed of light. General relativity extends the theory to include gravity, describing it as the curvature of spacetime caused by mass and energy."
    },
    {
        "question": "What are the benefits of regular exercise?",
        "response": "Regular exercise offers numerous health benefits, including improved cardiovascular health, increased muscle strength, and better weight management. It also enhances mood, reduces the risk of chronic diseases such as diabetes, and promotes overall well-being."
    }
]

# %%
eval_llm = EvalLLM(openai_api_key=OPENAI_API_KEY)

res = eval_llm.evaluate(
    data = good_data,
    checks = [Evals.RESPONSE_CONCISENESS]
)
# Out:
# 2023-12-18 14:56:53.675 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-18 14:57:02.080 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-18 14:57:12.490 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain

# %%
print(json.dumps(res,indent=3))
# Out:
# [
#    {
#       "question": "What are the primary components of a cell?",
#       "response": "A cell typically consists of a cell membrane, cytoplasm, and a nucleus. The cell membrane encloses the cell and regulates the passage of substances in and out. The cytoplasm contains organelles and other cellular structures, while the nucleus houses the genetic material.",
#       "score_response_conciseness": 1.0,
#       "explanation_response_conciseness": "1. The question asks for the primary components of a cell.\n2. The response provides three primary components: cell membrane, cytoplasm, and nucleus.\n3. The response also provides additional information about the functions of each component.\n4. The additional information about the functions of each component is relevant and directly related to the primary components of a cell.\n5. Therefore, the generated answer has no additional irrelevant information.\n\nScore: 1.0\n1.0"
#    },
#    {
#       "question": "How does photosynthesis work?",
#       "response": "Photosynthesis is the process by which plants, algae, and some bacteria convert light energy into chemical energy. It involves the absorption of sunlight by chlorophyll, which is used to synthesize glucose from carbon dioxide and water. Oxygen is released as a byproduct.",
#       "score_response_conciseness": 1.0,
#       "explanation_response_conciseness": "1. Read the question: \"How does photosynthesis work?\"\n2. Read the response: \"Photosynthesis is the process by which plants, algae, and some bacteria convert light energy into chemical energy. It involves the absorption of sunlight by chlorophyll, which is used to synthesize glucose from carbon dioxide and water. Oxygen is released as a byproduct.\"\n3. Compare the response to the question:\n   - The response provides a clear and concise explanation of how photosynthesis works.\n   - The response includes relevant information about the conversion of light energy into chemical energy, the role of chlorophyll in absorbing sunlight, and the synthesis of glucose from carbon dioxide and water.\n   - The response also mentions the release of oxygen as a byproduct, which is directly related to the process of photosynthesis.\n4. There is no additional irrelevant information in the response.\n5. Based on the above analysis, the generated answer has no additional irrelevant information.\n6. Print the score: 1.0"
#    },
#    {
#       "question": "What are the key features of the Python programming language?",
#       "response": "Python is a high-level, interpreted programming language known for its readability and simplicity. It supports object-oriented, imperative, and functional programming paradigms. Python has a large standard library, dynamic typing, and automatic memory management.",
#       "score_response_conciseness": 1.0,
#       "explanation_response_conciseness": "1. The question asks for the key features of the Python programming language.\n2. The response begins by stating that Python is a high-level, interpreted programming language known for its readability and simplicity. This is relevant information as it describes the nature of the language.\n3. The response then mentions that Python supports object-oriented, imperative, and functional programming paradigms. This is also relevant information as it describes the programming paradigms that Python supports.\n4. The response further states that Python has a large standard library, dynamic typing, and automatic memory management. These are additional key features of the Python programming language, which are directly relevant to the question.\n5. There is no additional irrelevant information in the response. All the information provided is directly related to the key features of the Python programming language.\n\nBased on this reasoning, the correct answer is C. The generated answer has no additional irrelevant information.\n\nThe score is 1.0\n1.0"
#    },
#    {
#       "question": "Explain the theory of relativity.",
#       "response": "The theory of relativity, developed by Albert Einstein, consists of two major parts: special relativity and general relativity. Special relativity deals with objects moving at constant speeds, particularly those moving close to the speed of light. General relativity extends the theory to include gravity, describing it as the curvature of spacetime caused by mass and energy.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. Read the question: \"Explain the theory of relativity.\"\n2. Read the response: \"The theory of relativity, developed by Albert Einstein, consists of two major parts: special relativity and general relativity. Special relativity deals with objects moving at constant speeds, particularly those moving close to the speed of light. General relativity extends the theory to include gravity, describing it as the curvature of spacetime caused by mass and energy.\"\n3. Compare the response to the question to determine if there is any additional irrelevant information.\n4. The response provides a brief introduction to the theory of relativity, mentioning that it was developed by Albert Einstein and consists of two major parts: special relativity and general relativity. This information is relevant and directly addresses the question.\n5. The response then goes on to explain special relativity and general relativity, which are the two major parts of the theory. This information is also directly relevant to the question.\n6. There is no additional irrelevant information in the response.\n7. Based on the above analysis, the generated answer has no additional irrelevant information.\n8. Print the score associated with choice C: 1.0\n9. Repeat the score on a new line: 1.0"
#    },
#    {
#       "question": "What are the benefits of regular exercise?",
#       "response": "Regular exercise offers numerous health benefits, including improved cardiovascular health, increased muscle strength, and better weight management. It also enhances mood, reduces the risk of chronic diseases such as diabetes, and promotes overall well-being.",
#       "score_response_conciseness": 1.0,
#       "explanation_response_conciseness": "1. Read the question: \"What are the benefits of regular exercise?\"\n2. Read the response: \"Regular exercise offers numerous health benefits, including improved cardiovascular health, increased muscle strength, and better weight management. It also enhances mood, reduces the risk of chronic diseases such as diabetes, and promotes overall well-being.\"\n3. Compare the response to the question and identify any additional irrelevant information.\n4. The response provides a list of specific benefits of regular exercise, including improved cardiovascular health, increased muscle strength, and better weight management. These are directly relevant to the question and not additional irrelevant information.\n5. The response also mentions that regular exercise enhances mood, reduces the risk of chronic diseases such as diabetes, and promotes overall well-being. These are also directly relevant to the question and not additional irrelevant information.\n6. Therefore, the response does not have any additional irrelevant information.\n7. Based on the reasoning above, the correct answer is C. The generated answer has no additional irrelevant information.\n\nScore: 1.0\n1.0"
#    }
# ]

# %% [markdown]
# Now, let's look at data with irrelevant responses.

# %%
bad_data = [
    {
        "question": "What are the primary components of a cell?",
        "response": "The primary components of a cell are crucial for its function. Speaking of components, the integration of software components in modern applications is a key challenge for developers. It requires careful consideration of architectural patterns and design principles."
    },
    {
        "question": "How does photosynthesis work?",
        "response": "Photosynthesis is a fascinating process in biology. By the way, the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms is an intriguing area of research. It involves mathematical modeling and algorithmic efficiency."
    },
    {
        "question": "What are the key features of the Python programming language?",
        "response": "Python, as a programming language, is known for its simplicity and readability. Speaking of readability, the importance of clear and concise technical documentation in software development cannot be overstated. It enhances collaboration among team members and ensures the maintainability of codebases over time."
    },
    {
        "question": "Explain the theory of relativity.",
        "response": "The theory of relativity is a cornerstone in physics. Interestingly, the theory of relativity has implications not only in physics but also in the field of project management. Time dilation, as described in the theory, is metaphorically analogous to project timelines, where careful planning and execution are crucial for success."
    },
    {
        "question": "What are the benefits of regular exercise?",
        "response": "Regular exercise has well-documented health benefits. On a related note, the importance of routine health check-ups in preventive healthcare cannot be emphasized enough. It allows for early detection of potential health issues and facilitates proactive management for individuals."
    }
]

# %%
eval_llm = EvalLLM(openai_api_key=OPENAI_API_KEY)

res = eval_llm.evaluate(
    data = bad_data,
    checks = [Evals.RESPONSE_CONCISENESS]
)
# Out:
# 2023-12-18 14:57:22.915 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-18 14:57:30.131 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-18 14:57:38.527 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain

# %%
print(json.dumps(res,indent=3))
# Out:
# [
#    {
#       "question": "What are the primary components of a cell?",
#       "response": "The primary components of a cell are crucial for its function. Speaking of components, the integration of software components in modern applications is a key challenge for developers. It requires careful consideration of architectural patterns and design principles.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. The question asks for the primary components of a cell.\n2. The response starts by acknowledging the importance of the primary components for the cell's function, which is relevant.\n3. However, the response then goes on to talk about the integration of software components in modern applications, architectural patterns, and design principles. This information is completely irrelevant to the question about the primary components of a cell.\n4. Therefore, the generated answer has additional irrelevant information.\n\nThe correct answer is A. The generated answer has a lot of additional irrelevant information.\n0.0\n0.0"
#    },
#    {
#       "question": "How does photosynthesis work?",
#       "response": "Photosynthesis is a fascinating process in biology. By the way, the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms is an intriguing area of research. It involves mathematical modeling and algorithmic efficiency.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. The question asks about how photosynthesis works.\n2. The response starts by acknowledging that photosynthesis is a fascinating process in biology, which is relevant to the question.\n3. However, the response then goes on to mention the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms, mathematical modeling, and algorithmic efficiency. These are not directly related to how photosynthesis works and can be considered as additional irrelevant information.\n4. Therefore, the generated answer has additional irrelevant information.\n\nThe correct answer is: A. The generated answer has a lot of additional irrelevant information.\n0.0"
#    },
#    {
#       "question": "What are the key features of the Python programming language?",
#       "response": "Python, as a programming language, is known for its simplicity and readability. Speaking of readability, the importance of clear and concise technical documentation in software development cannot be overstated. It enhances collaboration among team members and ensures the maintainability of codebases over time.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. The question asks for the key features of the Python programming language.\n2. The generated response starts by mentioning that Python is known for its simplicity and readability, which is relevant to the question.\n3. However, the response then goes on to talk about the importance of clear and concise technical documentation in software development, which is not directly related to the key features of Python.\n4. Therefore, the generated answer has additional irrelevant information.\n\nThe correct answer is: A. The generated answer has a lot of additional irrelevant information.\n0.0\n0.0"
#    },
#    {
#       "question": "Explain the theory of relativity.",
#       "response": "The theory of relativity is a cornerstone in physics. Interestingly, the theory of relativity has implications not only in physics but also in the field of project management. Time dilation, as described in the theory, is metaphorically analogous to project timelines, where careful planning and execution are crucial for success.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. The question asks for an explanation of the theory of relativity.\n2. The response begins by stating that the theory of relativity is a cornerstone in physics, which is relevant information.\n3. The response then adds that the theory of relativity has implications not only in physics but also in the field of project management. This is additional information that is not directly related to explaining the theory of relativity.\n4. The response further explains that time dilation, as described in the theory, is metaphorically analogous to project timelines, where careful planning and execution are crucial for success. This is another example of additional information that is not directly related to explaining the theory of relativity.\n\nBased on this reasoning, the generated answer has additional irrelevant information.\n\nScore: 0.0\n0.0"
#    },
#    {
#       "question": "What are the benefits of regular exercise?",
#       "response": "Regular exercise has well-documented health benefits. On a related note, the importance of routine health check-ups in preventive healthcare cannot be emphasized enough. It allows for early detection of potential health issues and facilitates proactive management for individuals.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. The question asks about the benefits of regular exercise.\n2. The response starts by acknowledging that regular exercise has well-documented health benefits, which directly addresses the question.\n3. However, the response then goes on to mention the importance of routine health check-ups in preventive healthcare, early detection of potential health issues, and proactive management for individuals.\n4. While these points may be valid and related to health, they are not directly addressing the benefits of regular exercise as asked in the question.\n5. Therefore, the response contains additional irrelevant information.\n\nBased on this reasoning, the correct answer is:\n\nA. The generated answer has a lot of additional irrelevant information.\n\n0.0\n0.0"
#    }
# ]
