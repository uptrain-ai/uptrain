# %% [markdown]
# <h1 align="center">
#   <a href="https://uptrain.ai">
#     <img width="300" src="https://user-images.githubusercontent.com/108270398/214240695-4f958b76-c993-4ddd-8de6-8668f4d0da84.png" alt="uptrain">
#   </a>
# </h1>

# %% [markdown]
# <h1 style="text-align: center;">Evaluating Response Conciseness</h1>

# %% [markdown]
# **What is Response Conciseness?**: Response conciseness refers to the quality of a generated response in terms of being clear, brief, and to the point. A concise response effectively conveys the necessary information without unnecessary elaboration or verbosity. It focuses on addressing the core of the question or query in a straightforward manner.
#
# In the context of natural language processing and AI-generated responses, concise answers are valuable as they enhance user experience by delivering information efficiently. Extraneous details or overly complex explanations can lead to decreased clarity and user understanding.
#
# For example, if the question is "What are the advantages of adopting cloud computing?", a concise response would highlight key benefits without unnecessary details. An example concise response could be: "Cloud computing offers scalability, cost efficiency, and accessibility to resources over the internet."
#
# **Data schema**: The data schema required for evaluating response conciseness would include the same columns as mentioned in the Response Relevance example:
#
# | Column Name | Description |
# | ----------- | ----------- |
# | question | The question asked by the user |
# | response | The response generated by the model |

# %% [markdown]
# Install UpTrain by running 'pip install uptrain'

# %%
from uptrain import EvalLLM, Evals
import json

OPENAI_API_KEY = "sk-*****************"  # Insert your OpenAI key here

# %% [markdown]
# Let's first look at data with relevant responses.

# %%
good_data = [
    {
        "question": "What are the primary components of a cell?",
        "response": "A cell comprises a cell membrane, cytoplasm, and nucleus. The cell membrane regulates substance passage, the cytoplasm contains organelles, and the nucleus houses genetic material."
    },
    {
        "question": "How does photosynthesis work?",
        "response": "Photosynthesis converts light energy into chemical energy in plants, algae, and some bacteria. Chlorophyll absorbs sunlight, synthesizing glucose from carbon dioxide and water, with oxygen released as a byproduct."
    },
    {
        "question": "What are the key features of the Python programming language?",
        "response": "Python is a high-level, interpreted language known for readability. It supports object-oriented, imperative, and functional programming with a large standard library, dynamic typing, and automatic memory management."
    }
]

# %%
eval_llm = EvalLLM(openai_api_key=OPENAI_API_KEY)

res = eval_llm.evaluate(
    data = good_data,
    checks = [Evals.RESPONSE_CONCISENESS]
)
# Out:
# 2023-12-19 16:31:19.181 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-19 16:31:28.810 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-19 16:31:36.472 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain

# %%
print(json.dumps(res,indent=3))
# Out:
# [
#    {
#       "question": "What are the primary components of a cell?",
#       "response": "A cell comprises a cell membrane, cytoplasm, and nucleus. The cell membrane regulates substance passage, the cytoplasm contains organelles, and the nucleus houses genetic material.",
#       "score_response_conciseness": 1.0,
#       "explanation_response_conciseness": "1. The question asks for the primary components of a cell.\n2. The provided response states that a cell comprises a cell membrane, cytoplasm, and nucleus.\n3. The response then goes on to provide additional information about the functions of each component.\n4. The additional information about the functions of each component is relevant and directly related to the primary components of a cell.\n5. Therefore, the generated answer has no additional irrelevant information.\n\nScore: 1.0\n1.0"
#    },
#    {
#       "question": "How does photosynthesis work?",
#       "response": "Photosynthesis converts light energy into chemical energy in plants, algae, and some bacteria. Chlorophyll absorbs sunlight, synthesizing glucose from carbon dioxide and water, with oxygen released as a byproduct.",
#       "score_response_conciseness": 1.0,
#       "explanation_response_conciseness": "1. Read the question: \"How does photosynthesis work?\"\n2. Read the response: \"Photosynthesis converts light energy into chemical energy in plants, algae, and some bacteria. Chlorophyll absorbs sunlight, synthesizing glucose from carbon dioxide and water, with oxygen released as a byproduct.\"\n3. Compare the response to the question to determine if there is any additional irrelevant information.\n4. The response provides a clear and concise explanation of how photosynthesis works, without any additional irrelevant information.\n5. The response directly addresses the question and does not include any unrelated or unnecessary details.\n6. Therefore, the generated answer has no additional irrelevant information.\n\nThe correct answer is C: The generated answer has no additional irrelevant information.\n1.0\n1.0"
#    },
#    {
#       "question": "What are the key features of the Python programming language?",
#       "response": "Python is a high-level, interpreted language known for readability. It supports object-oriented, imperative, and functional programming with a large standard library, dynamic typing, and automatic memory management.",
#       "score_response_conciseness": 1.0,
#       "explanation_response_conciseness": "1. The question asks for the key features of the Python programming language.\n2. The response begins by stating that Python is a high-level, interpreted language known for readability. This is relevant information as it describes one of the key features of Python.\n3. The response then mentions that Python supports object-oriented, imperative, and functional programming. This is also relevant information as it describes another key feature of Python.\n4. The response further states that Python has a large standard library, dynamic typing, and automatic memory management. These are additional key features of Python.\n5. The response does not contain any irrelevant information. All the information provided is directly related to the key features of the Python programming language.\n\nBased on the above reasoning, the correct answer is:\n\nC. The generated answer has no additional irrelevant information.\n\nScore: 1.0"
#    }
# ]

# %% [markdown]
# Now, let's look at data with irrelevant responses.

# %%
bad_data = [
    {
        "question": "What are the primary components of a cell?",
        "response": "The primary components of a cell are crucial for its function. Speaking of components, the integration of software components in modern applications is a key challenge for developers. It requires careful consideration of architectural patterns and design principles."
    },
    {
        "question": "How does photosynthesis work?",
        "response": "Photosynthesis is a fascinating process in biology. By the way, the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms is an intriguing area of research. It involves mathematical modeling and algorithmic efficiency."
    },
    {
        "question": "What are the key features of the Python programming language?",
        "response": "Python, as a programming language, is known for its simplicity and readability. Speaking of readability, the importance of clear and concise technical documentation in software development cannot be overstated. It enhances collaboration among team members and ensures the maintainability of codebases over time."
    }
]

# %%
eval_llm = EvalLLM(openai_api_key=OPENAI_API_KEY)

res = eval_llm.evaluate(
    data = bad_data,
    checks = [Evals.RESPONSE_CONCISENESS]
)
# Out:
# 2023-12-19 16:28:15.094 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-19 16:28:22.460 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-19 16:28:28.708 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain

# %%
print(json.dumps(res,indent=3))
# Out:
# [
#    {
#       "question": "What are the primary components of a cell?",
#       "response": "The primary components of a cell are crucial for its function. Speaking of components, the integration of software components in modern applications is a key challenge for developers. It requires careful consideration of architectural patterns and design principles.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. The question asks for the primary components of a cell.\n2. The response starts by acknowledging that the primary components of a cell are crucial for its function, which is relevant.\n3. However, the response then goes on to talk about the integration of software components in modern applications, architectural patterns, and design principles, which are not relevant to the question about the primary components of a cell.\n4. Therefore, the generated answer has additional irrelevant information.\n\nThe correct answer is A. The generated answer has a lot of additional irrelevant information.\n0.0\n0.0"
#    },
#    {
#       "question": "How does photosynthesis work?",
#       "response": "Photosynthesis is a fascinating process in biology. By the way, the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms is an intriguing area of research. It involves mathematical modeling and algorithmic efficiency.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. The question asks about how photosynthesis works.\n2. The response starts by acknowledging that photosynthesis is a fascinating process in biology, which is relevant to the question.\n3. The response then goes on to mention the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms, which is not directly related to how photosynthesis works.\n4. The response further mentions mathematical modeling and algorithmic efficiency, which are also not directly related to how photosynthesis works.\n5. Therefore, the response contains additional irrelevant information.\n\nThe generated answer has a lot of additional irrelevant information.\n0.0"
#    },
#    {
#       "question": "What are the key features of the Python programming language?",
#       "response": "Python, as a programming language, is known for its simplicity and readability. Speaking of readability, the importance of clear and concise technical documentation in software development cannot be overstated. It enhances collaboration among team members and ensures the maintainability of codebases over time.",
#       "score_response_conciseness": 0.0,
#       "explanation_response_conciseness": "1. The question asks for the key features of the Python programming language.\n2. The response starts by mentioning that Python is known for its simplicity and readability, which is relevant to the question.\n3. However, the response then goes on to talk about the importance of clear and concise technical documentation in software development, which is not directly related to the key features of Python.\n4. Therefore, the generated answer has additional irrelevant information.\n\nThe correct answer is A. The generated answer has a lot of additional irrelevant information.\n0.0\n0.0"
#    }
# ]
