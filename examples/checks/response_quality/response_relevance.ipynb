# %% [markdown]
# <h1 align="center">
#   <a href="https://uptrain.ai">
#     <img width="300" src="https://user-images.githubusercontent.com/108270398/214240695-4f958b76-c993-4ddd-8de6-8668f4d0da84.png" alt="uptrain">
#   </a>
# </h1>

# %% [markdown]
# <h1 style="text-align: center;">Evaluating Response Relevance</h1>

# %% [markdown]
# **What is Response Relevance?**: Response relevance is the measure of how relevant the generated response is to the question asked. It is a measure of how well the response addresses the question asked and if it contains any additional information that is not relevant to the question asked.
#
# For example, if the question asked is "Can you tell me about the benefits of renewable energy?", a relevant response would be "Renewable energy is energy that is collected from renewable resources, which are naturally replenished on a human timescale, such as sunlight, wind, rain, tides, waves, and geothermal heat." An irrelevant response could be "The concept of electricity dates back to ancient times when people observed static electricity from rubbing certain materials together. It's fascinating how electricity has evolved over the centuries, leading to the development of various technologies."
#
# **Data schema**: The data schema required for this evaluation is as follows:
#
# | Column Name | Description |
# | ----------- | ----------- |
# | question | The question asked by the user |
# | response | The response generated by the model |

# %% [markdown]
# Install UpTrain by running 'pip install uptrain'

# %%
from uptrain import EvalLLM, Evals
import json

OPENAI_API_KEY = "sk-*****************"  # Insert your OpenAI key here

# %% [markdown]
# Let's first look at data with relevant responses.

# %%
good_data = [
    {
        "question": "What are the primary components of a cell?",
        "response": "A cell typically consists of a cell membrane, cytoplasm, and a nucleus. The cell membrane encloses the cell and regulates the passage of substances in and out. The cytoplasm contains organelles and other cellular structures, while the nucleus houses the genetic material."
    },
    {
        "question": "How does photosynthesis work?",
        "response": "Photosynthesis is the process by which plants, algae, and some bacteria convert light energy into chemical energy. It involves the absorption of sunlight by chlorophyll, which is used to synthesize glucose from carbon dioxide and water. Oxygen is released as a byproduct."
    },
    {
        "question": "What are the key features of the Python programming language?",
        "response": "Python is a high-level, interpreted programming language known for its readability and simplicity. It supports object-oriented, imperative, and functional programming paradigms. Python has a large standard library, dynamic typing, and automatic memory management."
    },
    {
        "question": "Explain the theory of relativity.",
        "response": "The theory of relativity, developed by Albert Einstein, consists of two major parts: special relativity and general relativity. Special relativity deals with objects moving at constant speeds, particularly those moving close to the speed of light. General relativity extends the theory to include gravity, describing it as the curvature of spacetime caused by mass and energy."
    },
    {
        "question": "What are the benefits of regular exercise?",
        "response": "Regular exercise offers numerous health benefits, including improved cardiovascular health, increased muscle strength, and better weight management. It also enhances mood, reduces the risk of chronic diseases such as diabetes, and promotes overall well-being."
    }
]

# %%
eval_llm = EvalLLM(openai_api_key=OPENAI_API_KEY)

res = eval_llm.evaluate(
    data = good_data,
    checks = [Evals.RESPONSE_RELEVANCE]
)
# Out:
# 2023-12-15 16:53:22.043 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-15 16:53:33.411 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-15 16:53:44.074 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain

# %%
print(json.dumps(res,indent=3))
# Out:
# [
#    {
#       "question": "What are the primary components of a cell?",
#       "response": "A cell typically consists of a cell membrane, cytoplasm, and a nucleus. The cell membrane encloses the cell and regulates the passage of substances in and out. The cytoplasm contains organelles and other cellular structures, while the nucleus houses the genetic material.",
#       "score_response_relevance": 1.0,
#       "explanation_response_relevance": "1. The question asks for the primary components of a cell.\n2. The provided response states that a cell typically consists of a cell membrane, cytoplasm, and a nucleus.\n3. The information provided in the response directly answers the question and does not include any additional irrelevant information.\n4. The response is concise and focused on the primary components of a cell.\n5. There are no logical fallacies, incorrect assumptions, or errors in reasoning in the response.\n6. Therefore, the generated answer has no additional irrelevant information.\n\nScore: 1.0\n1.0\nThe machine-generated response provides a relevant and adequate answer to the user query. It identifies the primary components of a cell, which are the cell membrane, cytoplasm, and nucleus. It also briefly explains the functions of each component. The response directly addresses the question and provides the necessary information. Therefore, the correct choice is C. \n\nScore: 1.0\n1.0"
#    },
#    {
#       "question": "How does photosynthesis work?",
#       "response": "Photosynthesis is the process by which plants, algae, and some bacteria convert light energy into chemical energy. It involves the absorption of sunlight by chlorophyll, which is used to synthesize glucose from carbon dioxide and water. Oxygen is released as a byproduct.",
#       "score_response_relevance": 1.0,
#       "explanation_response_relevance": "1. Read the question: \"How does photosynthesis work?\"\n2. Read the response: \"Photosynthesis is the process by which plants, algae, and some bacteria convert light energy into chemical energy. It involves the absorption of sunlight by chlorophyll, which is used to synthesize glucose from carbon dioxide and water. Oxygen is released as a byproduct.\"\n3. Compare the response to the question:\n   - The response provides a clear and concise explanation of how photosynthesis works.\n   - It mentions the key components involved in photosynthesis: plants, algae, and some bacteria.\n   - It explains that photosynthesis converts light energy into chemical energy.\n   - It describes the role of chlorophyll in absorbing sunlight and synthesizing glucose.\n   - It states that oxygen is released as a byproduct.\n4. There is no additional irrelevant information in the response. It directly addresses the question without any unnecessary details.\n5. Based on the above analysis, the correct answer is C. The generated answer has no additional irrelevant information.\n\nScore: 1.0\n1.0\n1. The question asks about how photosynthesis works.\n2. The response begins by stating that photosynthesis is the process by which plants, algae, and some bacteria convert light energy into chemical energy. This is directly relevant to the question.\n3. The response further explains that photosynthesis involves the absorption of sunlight by chlorophyll, which is used to synthesize glucose from carbon dioxide and water. This provides additional details on the process of photosynthesis.\n4. The response concludes by mentioning that oxygen is released as a byproduct of photosynthesis. This is another important aspect of how photosynthesis works.\n5. The response covers all the key points of how photosynthesis works, including the conversion of light energy into chemical energy, the role of chlorophyll, the synthesis of glucose, and the release of oxygen.\n6. Therefore, the generated answer answers the given question adequately.\n\nThe score is 1.0\n1.0"
#    },
#    {
#       "question": "What are the key features of the Python programming language?",
#       "response": "Python is a high-level, interpreted programming language known for its readability and simplicity. It supports object-oriented, imperative, and functional programming paradigms. Python has a large standard library, dynamic typing, and automatic memory management.",
#       "score_response_relevance": 1.0,
#       "explanation_response_relevance": "1. The question asks for the key features of the Python programming language.\n2. The response starts by stating that Python is a high-level, interpreted programming language known for its readability and simplicity. This is relevant information as it describes the nature of Python.\n3. The response then mentions that Python supports object-oriented, imperative, and functional programming paradigms. This is also relevant information as it highlights the versatility of Python.\n4. The response further states that Python has a large standard library, dynamic typing, and automatic memory management. These are additional key features of Python that are directly related to its functionality.\n5. There is no additional irrelevant information in the response. All the information provided is directly related to the key features of Python.\n\nBased on this reasoning, the correct answer is C. The generated answer has no additional irrelevant information.\n\nScore: 1.0\n1. The question asks for the key features of the Python programming language.\n2. The response mentions several key features of Python, including its readability, simplicity, support for different programming paradigms, large standard library, dynamic typing, and automatic memory management.\n3. The response directly addresses the question by providing a list of key features of Python.\n4. The response is relevant and adequately answers the user query.\n\nBased on this reasoning, the correct answer is C. The generated answer answers the given question adequately.\n\nScore: 1.0\n1.0"
#    },
#    {
#       "question": "Explain the theory of relativity.",
#       "response": "The theory of relativity, developed by Albert Einstein, consists of two major parts: special relativity and general relativity. Special relativity deals with objects moving at constant speeds, particularly those moving close to the speed of light. General relativity extends the theory to include gravity, describing it as the curvature of spacetime caused by mass and energy.",
#       "score_response_relevance": 1.0,
#       "explanation_response_relevance": "1. Read the question: \"Explain the theory of relativity.\"\n2. Read the response: \"The theory of relativity, developed by Albert Einstein, consists of two major parts: special relativity and general relativity. Special relativity deals with objects moving at constant speeds, particularly those moving close to the speed of light. General relativity extends the theory to include gravity, describing it as the curvature of spacetime caused by mass and energy.\"\n3. Compare the response to the question to determine if there is any additional irrelevant information.\n4. The response provides a brief introduction to the theory of relativity, mentioning that it was developed by Albert Einstein and consists of two major parts: special relativity and general relativity.\n5. The response then goes on to explain special relativity, which deals with objects moving at constant speeds, particularly those moving close to the speed of light.\n6. Finally, the response explains general relativity, which extends the theory to include gravity and describes it as the curvature of spacetime caused by mass and energy.\n7. The response does not contain any additional irrelevant information. It provides a concise and accurate explanation of the theory of relativity.\n8. Based on the above analysis, the correct answer is C. The generated answer has no additional irrelevant information.\n\nScore: 1.0\n1.0\n1. The question asks for an explanation of the theory of relativity.\n2. The response begins by stating that the theory of relativity consists of two major parts: special relativity and general relativity.\n3. The response then goes on to explain special relativity, which deals with objects moving at constant speeds, particularly those moving close to the speed of light.\n4. The response also explains general relativity, which extends the theory to include gravity and describes it as the curvature of spacetime caused by mass and energy.\n\nBased on the reasoning above, the generated answer answers the given question adequately by providing an explanation of the theory of relativity, including its two major parts and their respective concepts.\n\nThe score is 1.0.\n1.0"
#    },
#    {
#       "question": "What are the benefits of regular exercise?",
#       "response": "Regular exercise offers numerous health benefits, including improved cardiovascular health, increased muscle strength, and better weight management. It also enhances mood, reduces the risk of chronic diseases such as diabetes, and promotes overall well-being.",
#       "score_response_relevance": 1.0,
#       "explanation_response_relevance": "1. Read the question: \"What are the benefits of regular exercise?\"\n2. Read the response: \"Regular exercise offers numerous health benefits, including improved cardiovascular health, increased muscle strength, and better weight management. It also enhances mood, reduces the risk of chronic diseases such as diabetes, and promotes overall well-being.\"\n3. Compare the response to the question to determine if there is any additional irrelevant information.\n4. The response directly addresses the question and provides relevant information about the benefits of regular exercise.\n5. There is no additional irrelevant information in the response.\n6. Based on the reasoning above, the correct answer is C. The generated answer has no additional irrelevant information.\n\n1.0\nThe machine-generated response provides a relevant and adequate answer to the user's question. It lists several benefits of regular exercise, including improved cardiovascular health, increased muscle strength, better weight management, enhanced mood, reduced risk of chronic diseases, and overall well-being. These benefits directly address the question about the benefits of regular exercise. Therefore, the generated answer answers the given question adequately.\n\nScore: 1.0\n1.0"
#    }
# ]

# %% [markdown]
# Now, let's look at data with irrelevant responses.

# %%
bad_data = [
    {
        "question": "What are the primary components of a cell?",
        "response": "The primary components of a cell are crucial for its function. Speaking of components, the integration of software components in modern applications is a key challenge for developers. It requires careful consideration of architectural patterns and design principles."
    },
    {
        "question": "How does photosynthesis work?",
        "response": "Photosynthesis is a fascinating process in biology. By the way, the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms is an intriguing area of research. It involves mathematical modeling and algorithmic efficiency."
    },
    {
        "question": "What are the key features of the Python programming language?",
        "response": "Python, as a programming language, is known for its simplicity and readability. Speaking of readability, the importance of clear and concise technical documentation in software development cannot be overstated. It enhances collaboration among team members and ensures the maintainability of codebases over time."
    },
    {
        "question": "Explain the theory of relativity.",
        "response": "The theory of relativity is a cornerstone in physics. Interestingly, the theory of relativity has implications not only in physics but also in the field of project management. Time dilation, as described in the theory, is metaphorically analogous to project timelines, where careful planning and execution are crucial for success."
    },
    {
        "question": "What are the benefits of regular exercise?",
        "response": "Regular exercise has well-documented health benefits. On a related note, the importance of routine health check-ups in preventive healthcare cannot be emphasized enough. It allows for early detection of potential health issues and facilitates proactive management for individuals."
    }
]

# %%
eval_llm = EvalLLM(openai_api_key=OPENAI_API_KEY)

res = eval_llm.evaluate(
    data = bad_data,
    checks = [Evals.RESPONSE_RELEVANCE]
)
# Out:
# 2023-12-15 16:53:55.010 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-15 16:54:04.330 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain
# 2023-12-15 16:54:11.585 | INFO     | uptrain.framework.evalllm:evaluate:100 - Sending evaluation request for rows 0 to <50 to the Uptrain

# %%
print(json.dumps(res,indent=3))
# Out:
# [
#    {
#       "question": "What are the primary components of a cell?",
#       "response": "The primary components of a cell are crucial for its function. Speaking of components, the integration of software components in modern applications is a key challenge for developers. It requires careful consideration of architectural patterns and design principles.",
#       "score_response_relevance": 0.0,
#       "explanation_response_relevance": "1. The question asks for the primary components of a cell.\n2. The response starts by acknowledging the importance of the primary components for the cell's function, which is relevant.\n3. However, the response then veers off-topic and starts discussing the integration of software components in modern applications, architectural patterns, and design principles. This information is irrelevant to the question about the primary components of a cell.\n4. Therefore, the generated answer has additional irrelevant information.\n\nThe correct answer is A. The generated answer has a lot of additional irrelevant information.\n0.0\n0.0\n1. The question asks about the primary components of a cell.\n2. The response starts by acknowledging the importance of the primary components of a cell.\n3. However, the response then shifts to discussing the integration of software components in modern applications, which is not relevant to the question.\n4. The response does not provide any information about the actual primary components of a cell.\n5. Therefore, the generated answer doesn't answer the given question at all.\n\nScore: 0.0"
#    },
#    {
#       "question": "How does photosynthesis work?",
#       "response": "Photosynthesis is a fascinating process in biology. By the way, the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms is an intriguing area of research. It involves mathematical modeling and algorithmic efficiency.",
#       "score_response_relevance": 0.0,
#       "explanation_response_relevance": "1. The question asks about how photosynthesis works.\n2. The response starts by acknowledging that photosynthesis is a fascinating process in biology, which is relevant to the question.\n3. However, the response then goes on to mention the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms. This information is not directly related to how photosynthesis works and can be considered as additional irrelevant information.\n4. The response further mentions mathematical modeling and algorithmic efficiency, which are also not directly related to how photosynthesis works.\n5. Therefore, the generated answer has additional irrelevant information.\n\nThe generated answer has a lot of additional irrelevant information.\n0.0\n1. The question asks about how photosynthesis works.\n2. The response starts by acknowledging that photosynthesis is a fascinating process in biology, which is relevant to the question.\n3. However, the response then goes off on a tangent and discusses the implementation of photosynthesis algorithms in computer science for optimizing energy consumption in algorithms. This is not directly related to how photosynthesis works.\n4. The response concludes by mentioning that the implementation involves mathematical modeling and algorithmic efficiency, which is also not directly related to how photosynthesis works.\n\nBased on this reasoning, the generated answer only partially answers the given question.\n\n0.5\n0.5"
#    },
#    {
#       "question": "What are the key features of the Python programming language?",
#       "response": "Python, as a programming language, is known for its simplicity and readability. Speaking of readability, the importance of clear and concise technical documentation in software development cannot be overstated. It enhances collaboration among team members and ensures the maintainability of codebases over time.",
#       "score_response_relevance": 0.0,
#       "explanation_response_relevance": "1. The question asks for the key features of the Python programming language.\n2. The generated response starts by mentioning that Python is known for its simplicity and readability, which is relevant to the question.\n3. However, the response then goes on to talk about the importance of clear and concise technical documentation in software development, which is not directly related to the key features of Python.\n4. Therefore, the generated answer has additional irrelevant information.\n\nThe correct answer is: A. The generated answer has a lot of additional irrelevant information.\n0.0\n0.0\n1. The question asks for the key features of the Python programming language.\n2. The response starts by mentioning that Python is known for its simplicity and readability, which can be considered as key features.\n3. However, the response then shifts the focus to the importance of clear and concise technical documentation in software development, which is not directly related to the key features of Python.\n4. Therefore, the generated answer only partially answers the given question.\n\nThe correct answer is B: The generated answer only partially answers the given question.\n0.5\n0.5"
#    },
#    {
#       "question": "Explain the theory of relativity.",
#       "response": "The theory of relativity is a cornerstone in physics. Interestingly, the theory of relativity has implications not only in physics but also in the field of project management. Time dilation, as described in the theory, is metaphorically analogous to project timelines, where careful planning and execution are crucial for success.",
#       "score_response_relevance": 0.0,
#       "explanation_response_relevance": "1. The question asks for an explanation of the theory of relativity.\n2. The response begins by stating that the theory of relativity is a cornerstone in physics, which is relevant information.\n3. The response then adds that the theory of relativity has implications not only in physics but also in the field of project management. This is additional information that is not directly related to explaining the theory of relativity.\n4. The response further explains that time dilation, as described in the theory, is metaphorically analogous to project timelines, where careful planning and execution are crucial for success. This is another example of additional information that is not directly related to explaining the theory of relativity.\n\nBased on this reasoning, the generated answer has additional irrelevant information.\n\nScore: 0.0\n0.0\n1. The question asks for an explanation of the theory of relativity.\n2. The response starts by acknowledging that the theory of relativity is a cornerstone in physics.\n3. The response then goes on to mention that the theory of relativity has implications not only in physics but also in the field of project management.\n4. The response specifically mentions time dilation as described in the theory of relativity and compares it metaphorically to project timelines in project management.\n\nBased on the reasoning above, the generated answer only partially answers the given question. While it does mention the theory of relativity and its implications, it does not provide a detailed explanation of the theory itself. Therefore, the correct choice is B. \n\n0.5\n0.5"
#    },
#    {
#       "question": "What are the benefits of regular exercise?",
#       "response": "Regular exercise has well-documented health benefits. On a related note, the importance of routine health check-ups in preventive healthcare cannot be emphasized enough. It allows for early detection of potential health issues and facilitates proactive management for individuals.",
#       "score_response_relevance": 0.0,
#       "explanation_response_relevance": "1. The question asks about the benefits of regular exercise.\n2. The response starts by acknowledging that regular exercise has well-documented health benefits, which directly addresses the question.\n3. However, the response then goes on a tangent by mentioning the importance of routine health check-ups in preventive healthcare.\n4. This information about health check-ups is not directly relevant to the question about the benefits of regular exercise.\n5. Therefore, the generated answer has additional irrelevant information.\n\nThe correct answer is A. The generated answer has a lot of additional irrelevant information.\n0.0\n0.0\n1. The question asks about the benefits of regular exercise.\n2. The response starts by acknowledging the well-documented health benefits of regular exercise.\n3. However, the response then shifts to discussing the importance of routine health check-ups in preventive healthcare.\n4. While routine health check-ups may be related to overall health and well-being, they are not directly answering the question about the benefits of regular exercise.\n5. Therefore, the generated answer only partially answers the given question.\n\nThe correct answer is B: The generated answer only partially answers the given question.\n0.5\n0.5"
#    }
# ]
